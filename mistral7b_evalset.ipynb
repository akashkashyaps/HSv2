# %%
import pandas as pd
import numpy as np

# %%
results_set = pd.read_csv('Results_Fusion.csv')
test_set = pd.read_csv('ROBIN_FINAL_TEST_SET.csv')

# %%
import re
# Define a function to extract context and answer using regular expressions
def extract_context_answer(text):
    match = re.search(r'CONTEXT:(.*?)QUESTION:(.*?)INST(.*)$', text, re.DOTALL)
    if match:
        context = match.group(1).strip()
        answer = match.group(3).strip().replace("\n", " ").replace("\r", "").replace("[/", "").replace("]", "")
        return context, answer
    else:
        return None, None

# %%
results_set[['context', 'answer']] = results_set['Answer'].apply(lambda x: pd.Series(extract_context_answer(x)))
results_set
# Out:
#                                               Question  \
# 0     What are the academic qualifications and foun...
# 1    Which BSc (Hons) program merges math/data scie...
# 2     What are the key components and objectives of...
# 3     What is the main objective of the PRAVE Proje...
# 4     What is the purpose of integrating an in-vehi...
# ..                                                 ...
# 391   What are the benefits of participating in the...
# 392   What benefits does the Microsoft certified Az...
# 393   What is the location of the study mode for th...
# 394   What are some examples of real-world industri...
# 395  Where does NTU focus on combining industry nee...
#
#                                                 Answer  Retrieval_Time  \
# 0    \n[INST]\n\nFor the purposes of this conversat...        0.058377
# 1    \n[INST]\n\nFor the purposes of this conversat...        0.011620
# 2    \n[INST]\n\nFor the purposes of this conversat...        0.013463
# 3    \n[INST]\n\nFor the purposes of this conversat...        0.012276
# 4    \n[INST]\n\nFor the purposes of this conversat...        0.012720
# ..                                                 ...             ...
# 391  \n[INST]\n\nFor the purposes of this conversat...        0.013023
# 392  \n[INST]\n\nFor the purposes of this conversat...        0.012283
# 393  \n[INST]\n\nFor the purposes of this conversat...        0.012281
# 394  \n[INST]\n\nFor the purposes of this conversat...        0.012251
# 395  \n[INST]\n\nFor the purposes of this conversat...        0.012435
#
#      Chain_Time                                            context  \
# 0      3.195392  team and can support you to liaise with academ...
# 1      2.407203  Study Computer Science - Games Technology (wit...
# 2      4.651133  Drive with Confidence\n\nA Safe and Secure Dri...
# 3      1.953408  PRAVE Project (PRoactive Authentication and Ve...
# 4      1.998686  Integrating an in-vehicle intrusion detection ...
# ..          ...                                                ...
# 391    6.270468  year you will participate in the Microsoft cer...
# 392    4.065794  year you will participate in the Microsoft cer...
# 393    1.023240  What will I study on the Software Engineering ...
# 394    4.299342  You will have hands-on experience, applying yo...
# 395    2.796968  We focus on the Industrial and medical applica...
#
#                                                 answer
# 0     To pursue a career in Software Engineering, t...
# 1     The BSc (Hons) program that merges Math/Data ...
# 2     The key components and objectives of a secure...
# 3     The main objective of the PRAVE Project is to...
# 4     The purpose of integrating an in-vehicle intr...
# ..                                                 ...
# 391   The Microsoft Azure AI Fundamentals program o...
# 392   The Microsoft certified Azure AI Fundamentals...
# 393   The Software Engineering BSc (Hons) program i...
# 394   Some examples of real-world industrial applic...
# 395   At Nottingham Trent University (NTU), we focu...
#
# [396 rows x 6 columns]

# %%
results_set = results_set.drop(columns=['Answer'])
results_set
# Out:
#                                               Question  Retrieval_Time  \
# 0     What are the academic qualifications and foun...        0.058377
# 1    Which BSc (Hons) program merges math/data scie...        0.011620
# 2     What are the key components and objectives of...        0.013463
# 3     What is the main objective of the PRAVE Proje...        0.012276
# 4     What is the purpose of integrating an in-vehi...        0.012720
# ..                                                 ...             ...
# 391   What are the benefits of participating in the...        0.013023
# 392   What benefits does the Microsoft certified Az...        0.012283
# 393   What is the location of the study mode for th...        0.012281
# 394   What are some examples of real-world industri...        0.012251
# 395  Where does NTU focus on combining industry nee...        0.012435
#
#      Chain_Time                                            context  \
# 0      3.195392  team and can support you to liaise with academ...
# 1      2.407203  Study Computer Science - Games Technology (wit...
# 2      4.651133  Drive with Confidence\n\nA Safe and Secure Dri...
# 3      1.953408  PRAVE Project (PRoactive Authentication and Ve...
# 4      1.998686  Integrating an in-vehicle intrusion detection ...
# ..          ...                                                ...
# 391    6.270468  year you will participate in the Microsoft cer...
# 392    4.065794  year you will participate in the Microsoft cer...
# 393    1.023240  What will I study on the Software Engineering ...
# 394    4.299342  You will have hands-on experience, applying yo...
# 395    2.796968  We focus on the Industrial and medical applica...
#
#                                                 answer
# 0     To pursue a career in Software Engineering, t...
# 1     The BSc (Hons) program that merges Math/Data ...
# 2     The key components and objectives of a secure...
# 3     The main objective of the PRAVE Project is to...
# 4     The purpose of integrating an in-vehicle intr...
# ..                                                 ...
# 391   The Microsoft Azure AI Fundamentals program o...
# 392   The Microsoft certified Azure AI Fundamentals...
# 393   The Software Engineering BSc (Hons) program i...
# 394   Some examples of real-world industrial applic...
# 395   At Nottingham Trent University (NTU), we focu...
#
# [396 rows x 5 columns]

# %%
results_set = results_set.rename(columns={'Question': 'question'})
results_set
# Out:
#                                               question  Retrieval_Time  \
# 0     What are the academic qualifications and foun...        0.058377
# 1    Which BSc (Hons) program merges math/data scie...        0.011620
# 2     What are the key components and objectives of...        0.013463
# 3     What is the main objective of the PRAVE Proje...        0.012276
# 4     What is the purpose of integrating an in-vehi...        0.012720
# ..                                                 ...             ...
# 391   What are the benefits of participating in the...        0.013023
# 392   What benefits does the Microsoft certified Az...        0.012283
# 393   What is the location of the study mode for th...        0.012281
# 394   What are some examples of real-world industri...        0.012251
# 395  Where does NTU focus on combining industry nee...        0.012435
#
#      Chain_Time                                            context  \
# 0      3.195392  team and can support you to liaise with academ...
# 1      2.407203  Study Computer Science - Games Technology (wit...
# 2      4.651133  Drive with Confidence\n\nA Safe and Secure Dri...
# 3      1.953408  PRAVE Project (PRoactive Authentication and Ve...
# 4      1.998686  Integrating an in-vehicle intrusion detection ...
# ..          ...                                                ...
# 391    6.270468  year you will participate in the Microsoft cer...
# 392    4.065794  year you will participate in the Microsoft cer...
# 393    1.023240  What will I study on the Software Engineering ...
# 394    4.299342  You will have hands-on experience, applying yo...
# 395    2.796968  We focus on the Industrial and medical applica...
#
#                                                 answer
# 0     To pursue a career in Software Engineering, t...
# 1     The BSc (Hons) program that merges Math/Data ...
# 2     The key components and objectives of a secure...
# 3     The main objective of the PRAVE Project is to...
# 4     The purpose of integrating an in-vehicle intr...
# ..                                                 ...
# 391   The Microsoft Azure AI Fundamentals program o...
# 392   The Microsoft certified Azure AI Fundamentals...
# 393   The Software Engineering BSc (Hons) program i...
# 394   Some examples of real-world industrial applic...
# 395   At Nottingham Trent University (NTU), we focu...
#
# [396 rows x 5 columns]

# %%
evaluation_set_Mistral7B = pd.merge(results_set, test_set, on='question')
evaluation_set_Mistral7B
# Out:
#                                               question  Retrieval_Time  \
# 0     What are the academic qualifications and foun...        0.058377
# 1    Which BSc (Hons) program merges math/data scie...        0.011620
# 2     What are the key components and objectives of...        0.013463
# 3     What is the main objective of the PRAVE Proje...        0.012276
# 4     What is the purpose of integrating an in-vehi...        0.012720
# ..                                                 ...             ...
# 395   What are the benefits of participating in the...        0.013023
# 396   What benefits does the Microsoft certified Az...        0.012283
# 397   What is the location of the study mode for th...        0.012281
# 398   What are some examples of real-world industri...        0.012251
# 399  Where does NTU focus on combining industry nee...        0.012435
#
#      Chain_Time                                            context  \
# 0      3.195392  team and can support you to liaise with academ...
# 1      2.407203  Study Computer Science - Games Technology (wit...
# 2      4.651133  Drive with Confidence\n\nA Safe and Secure Dri...
# 3      1.953408  PRAVE Project (PRoactive Authentication and Ve...
# 4      1.998686  Integrating an in-vehicle intrusion detection ...
# ..          ...                                                ...
# 395    6.270468  year you will participate in the Microsoft cer...
# 396    4.065794  year you will participate in the Microsoft cer...
# 397    1.023240  What will I study on the Software Engineering ...
# 398    4.299342  You will have hands-on experience, applying yo...
# 399    2.796968  We focus on the Industrial and medical applica...
#
#                                                 answer  \
# 0     To pursue a career in Software Engineering, t...
# 1     The BSc (Hons) program that merges Math/Data ...
# 2     The key components and objectives of a secure...
# 3     The main objective of the PRAVE Project is to...
# 4     The purpose of integrating an in-vehicle intr...
# ..                                                 ...
# 395   The Microsoft Azure AI Fundamentals program o...
# 396   The Microsoft certified Azure AI Fundamentals...
# 397   The Software Engineering BSc (Hons) program i...
# 398   Some examples of real-world industrial applic...
# 399   At Nottingham Trent University (NTU), we focu...
#
#                                               contexts  \
# 0    ['- BSc (Hons), Mathematics with Data Science ...
# 1    ['- BSc (Hons), Mathematics with Data Science ...
# 2    ["A Safe and Secure Driving System to Mitigate...
# 3    ["A Safe and Secure Driving System to Mitigate...
# 4    ["A Safe and Secure Driving System to Mitigate...
# ..                                                 ...
# 395  ['You have the option to transfer between the ...
# 396  ['You have the option to transfer between the ...
# 397  ['Youâ€™re right at the start of your exciting...
# 398  ['your knowledge in real-world scenarios with ...
# 399  ['your knowledge in real-world scenarios with ...
#
#                                           ground_truth evolution_type  \
# 0    The academic qualifications required for a car...         simple
# 1    The BSc (Hons) in Mathematics with Data Scienc...      reasoning
# 2    The key components and objectives of a secure ...         simple
# 3    The main objective of the PRAVE Project is to ...         simple
# 4    The purpose of integrating an in-vehicle intru...         simple
# ..                                                 ...            ...
# 395  Participating in the Microsoft Azure AI Fundam...         simple
# 396  The Microsoft certified Azure AI Fundamentals ...         simple
# 397  The Software Engineering BSc (Hons) program is...         simple
# 398  Some examples of real-world industrial applica...         simple
# 399  NTU combines industry needs with AI prediction...  multi_context
#
#                                               metadata  episode_done
# 0    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 1    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 2    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 3    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 4    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# ..                                                 ...           ...
# 395  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 396  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 397  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 398  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 399  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
#
# [400 rows x 10 columns]

# %%
evaluation_set_Mistral7B.drop_duplicates(inplace=True)
evaluation_set_Mistral7B.dropna(inplace=True)
evaluation_set_Mistral7B
# Out:
#                                               question  Retrieval_Time  \
# 0     What are the academic qualifications and foun...        0.058377
# 1    Which BSc (Hons) program merges math/data scie...        0.011620
# 2     What are the key components and objectives of...        0.013463
# 3     What is the main objective of the PRAVE Proje...        0.012276
# 4     What is the purpose of integrating an in-vehi...        0.012720
# ..                                                 ...             ...
# 395   What are the benefits of participating in the...        0.013023
# 396   What benefits does the Microsoft certified Az...        0.012283
# 397   What is the location of the study mode for th...        0.012281
# 398   What are some examples of real-world industri...        0.012251
# 399  Where does NTU focus on combining industry nee...        0.012435
#
#      Chain_Time                                            context  \
# 0      3.195392  team and can support you to liaise with academ...
# 1      2.407203  Study Computer Science - Games Technology (wit...
# 2      4.651133  Drive with Confidence\n\nA Safe and Secure Dri...
# 3      1.953408  PRAVE Project (PRoactive Authentication and Ve...
# 4      1.998686  Integrating an in-vehicle intrusion detection ...
# ..          ...                                                ...
# 395    6.270468  year you will participate in the Microsoft cer...
# 396    4.065794  year you will participate in the Microsoft cer...
# 397    1.023240  What will I study on the Software Engineering ...
# 398    4.299342  You will have hands-on experience, applying yo...
# 399    2.796968  We focus on the Industrial and medical applica...
#
#                                                 answer  \
# 0     To pursue a career in Software Engineering, t...
# 1     The BSc (Hons) program that merges Math/Data ...
# 2     The key components and objectives of a secure...
# 3     The main objective of the PRAVE Project is to...
# 4     The purpose of integrating an in-vehicle intr...
# ..                                                 ...
# 395   The Microsoft Azure AI Fundamentals program o...
# 396   The Microsoft certified Azure AI Fundamentals...
# 397   The Software Engineering BSc (Hons) program i...
# 398   Some examples of real-world industrial applic...
# 399   At Nottingham Trent University (NTU), we focu...
#
#                                               contexts  \
# 0    ['- BSc (Hons), Mathematics with Data Science ...
# 1    ['- BSc (Hons), Mathematics with Data Science ...
# 2    ["A Safe and Secure Driving System to Mitigate...
# 3    ["A Safe and Secure Driving System to Mitigate...
# 4    ["A Safe and Secure Driving System to Mitigate...
# ..                                                 ...
# 395  ['You have the option to transfer between the ...
# 396  ['You have the option to transfer between the ...
# 397  ['Youâ€™re right at the start of your exciting...
# 398  ['your knowledge in real-world scenarios with ...
# 399  ['your knowledge in real-world scenarios with ...
#
#                                           ground_truth evolution_type  \
# 0    The academic qualifications required for a car...         simple
# 1    The BSc (Hons) in Mathematics with Data Scienc...      reasoning
# 2    The key components and objectives of a secure ...         simple
# 3    The main objective of the PRAVE Project is to ...         simple
# 4    The purpose of integrating an in-vehicle intru...         simple
# ..                                                 ...            ...
# 395  Participating in the Microsoft Azure AI Fundam...         simple
# 396  The Microsoft certified Azure AI Fundamentals ...         simple
# 397  The Software Engineering BSc (Hons) program is...         simple
# 398  Some examples of real-world industrial applica...         simple
# 399  NTU combines industry needs with AI prediction...  multi_context
#
#                                               metadata  episode_done
# 0    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 1    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 2    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 3    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 4    [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# ..                                                 ...           ...
# 395  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 396  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 397  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 398  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
# 399  [{'source': 'CS_OpenDay_General.docx', 'filena...          True
#
# [396 rows x 10 columns]

# %%
evaluation_set_Mistral7B.to_csv('evaluation_set_Fusion.csv', index=False)

# %%
mistral_inference = pd.read_csv('Mistral_time.csv')
mistral_inference

# %%
import re
# Define a function to extract context and answer using regular expressions
def extract_context_answer(text):
    match = re.search(r'CONTEXT:(.*?)QUESTION:(.*?)INST(.*)$', text, re.DOTALL)
    if match:
        context = match.group(1).strip()
        answer = match.group(3).strip().replace("\n", " ").replace("\r", "").replace("[/", "").replace("]", "")
        return context, answer
    else:
        return None, None

# %%
mistral_inference[['context', 'answer']] = mistral_inference['Answer'].apply(lambda x: pd.Series(extract_context_answer(x)))
mistral_inference

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')

# %%
# Function to count words in each row of the specified column
def count_words(answer):
    words = word_tokenize(answer)
    return len(words)

# %%
mistral_inference['total_tokens'] = mistral_inference['answer'].apply(count_words)
mistral_inference

# %%
mistral_inference["tokens_per_second"] = mistral_inference["total_tokens"] / mistral_inference["Time_Taken"]
mistral_inference

# %%
mistral_inference.drop(['Answer', 'context'], axis=1, inplace=True)
mistral_inference

# %%
mistral_inference.to_csv('mistral_inference.csv', index=False)
