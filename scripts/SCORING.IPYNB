# %%
import pandas as pd
import numpy as np

# %%
evaluation_set_Vanilla = pd.read_csv('evaluation_set_Vanilla.csv')
evaluation_set_Fusion = pd.read_csv('evaluation_set_Fusion.csv')
evaluation_set_Advanced = pd.read_csv('evaluation_set_Advanced.csv')
Vanilla_bertscore = pd.read_csv('Vanilla_bertscore.csv')
Fusion_bertscore = pd.read_csv('Fusion_bertscore.csv')
Advanced_bertscore = pd.read_csv('Advanced_bertscore.csv')

# %%
evaluation_set_Vanilla
# Out:
#                                               question  Retrieval_Time  \
# 0     What are the academic qualifications and foun...        0.012159
# 1    Which BSc (Hons) program merges math/data scie...        0.007140
# 2     What are the key components and objectives of...        0.007201
# 3     What is the main objective of the PRAVE Proje...        0.007095
# 4     What is the purpose of integrating an in-vehi...        0.006719
# ..                                                 ...             ...
# 391   What are the benefits of participating in the...        0.007059
# 392   What benefits does the Microsoft certified Az...        0.007471
# 393   What is the location of the study mode for th...        0.006931
# 394   What are some examples of real-world industri...        0.006871
# 395  Where does NTU focus on combining industry nee...        0.006853
#
#      Chain_Time                                            context  \
# ...

# %%
Vanilla_bertscore
# Out:
#                                               question  Retrieval_Time  \
# 0     What are the academic qualifications and foun...        0.012159
# 1    Which BSc (Hons) program merges math/data scie...        0.007140
# 2     What are the key components and objectives of...        0.007201
# 3     What is the main objective of the PRAVE Proje...        0.007095
# 4     What is the purpose of integrating an in-vehi...        0.006719
# ..                                                 ...             ...
# 391   What are the benefits of participating in the...        0.007059
# 392   What benefits does the Microsoft certified Az...        0.007471
# 393   What is the location of the study mode for th...        0.006931
# 394   What are some examples of real-world industri...        0.006871
# 395  Where does NTU focus on combining industry nee...        0.006853
#
#      Chain_Time                                   Vanilla_contexts  \
# ...

# %%
Retrieval_Time_mean = Advanced_bertscore['Retrieval_Time'].mean()
Retrieval_Time_std = Advanced_bertscore['Retrieval_Time'].std()
Chain_Time_mean = Advanced_bertscore['Chain_Time'].mean()
Chain_Time_std = Advanced_bertscore['Chain_Time'].std()
Bertscore_mean = Advanced_bertscore['contexts_bertscore_similarity'].mean()
Bertscore_std = Advanced_bertscore['contexts_bertscore_similarity'].std()

Retrieval_Time_mean, Retrieval_Time_std, Chain_Time_mean, Chain_Time_std, Bertscore_mean, Bertscore_std
# Out:
# (8.802878929509056,
#  2.718032247652199,
#  16.915807766143722,
#  10.016496169663439,
#  0.4582959527921195,
#  0.049671497349114135)
